# %% [markdown]
# # elasticsearch在Python requests中的应用
#
# 网址: https://es.xiaoleilu.com/

# %% [markdown]
# # basic

# %%
import requests, json
from pprint import pprint

# %%
r = requests.get("http://localhost:9200")
json.loads(r.text)
# Out:
# {'name': 'xgm_Node',
#  'cluster_name': 'xgm_Cluster',
#  'cluster_uuid': 'P_42AvtNT8WDvCtjIhKErQ',
#  'version': {'number': '7.5.1',
#   'build_flavor': 'default',
#   'build_type': 'tar',
#   'build_hash': '3ae9ac9a93c95bd0cdc054951cf95d88e1e18d96',
#   'build_date': '2019-12-16T22:57:37.835892Z',
#   'build_snapshot': False,
#   'lucene_version': '8.3.0',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %% [markdown]
# ### health

# %%
r = requests.get("http://localhost:9200/_cat/health?v")
print(r.text)
# Out:
# epoch      timestamp cluster     status node.total node.data shards pri relo init unassign pending_tasks max_task_wait_time active_shards_percent
# 1579799482 17:11:22  xgm_Cluster yellow          1         1      4   4    0    0        4             0                  -                 50.0%

# %% [markdown]
# # PUT 增加数据

# %%
data = {
    "first_name" : "John",
    "last_name" :  "Smith",
    "age" :        25,
    "about" :      "I love to go rock climbing",
    "interests": [ "sports", "music" ]
}
url = 'http://localhost:9200/megacorp/employee/1'
headers = {'Content-Type': 'application/json'}

r = requests.put(url, data = json.dumps(data), headers = headers)
json.loads(r.text)

# %%
data = {
    "first_name" :  "Jane",
    "last_name" :   "Smith",
    "age" :         32,
    "about" :       "I like to collect rock albums",
    "interests":  [ "music" ]
}
url = 'http://localhost:9200/megacorp/employee/2'
headers = {'Content-Type': 'application/json'}

r = requests.put(url, data = json.dumps(data), headers = headers)
json.loads(r.text)
# Out:
# {'_id': '2',
#  '_index': 'megacorp',
#  '_primary_term': 1,
#  '_seq_no': 2,
#  '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#  '_type': 'employee',
#  '_version': 1,
#  'result': 'created'}

# %%
data = {
    "first_name" :  "Douglas",
    "last_name" :   "Fir",
    "age" :         35,
    "about":        "I like to build cabinets",
    "interests":  [ "forestry" ]
}
url = 'http://localhost:9200/megacorp/employee/3'
headers = {'Content-Type': 'application/json'}

r = requests.put(url, data = json.dumps(data), headers = headers)
json.loads(r.text)
# Out:
# {'_index': 'megacorp',
#  '_type': 'employee',
#  '_id': '3',
#  '_version': 1,
#  'result': 'created',
#  '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#  '_seq_no': 5,
#  '_primary_term': 1}

# %%
r = requests.get("http://localhost:9200/megacorp/employee/1")
json.loads(r.text)
# Out:
# {'_index': 'megacorp',
#  '_type': 'employee',
#  '_id': '1',
#  '_version': 3,
#  '_seq_no': 6,
#  '_primary_term': 1,
#  'found': True,
#  '_source': {'first_name': 'John',
#   'last_name': 'Smith',
#   'age': 25,
#   'about': 'I love to go rock climbing',
#   'interests': ['sports', 'music']}}

# %% [markdown]
# # Indexing documents in bulkedit
#
# `curl -H "Content-Type: application/json" -XPOST "localhost:9200/bank/_bulk?pretty&refresh" --data-binary "@accounts.json"`
#
# `curl "localhost:9200/_cat/indices?v"`

# %%
# data = {
#     "data-binary" :  "@accounts.json",
# } # wrong usage

with open('accounts.json', 'r') as f1:
    data = f1.read()
url = 'http://localhost:9200/bank/_bulk?pretty&refresh'
headers = {'Content-Type': 'application/json'}

r = requests.post(url = url, headers = headers, data=data)
json.loads(r.text)
# Out:
# {'took': 236,
#  'errors': False,
#  'items': [{'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '1',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1000,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '6',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1001,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '13',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1002,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '18',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1003,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '20',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1004,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '25',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1005,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '32',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1006,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '37',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1007,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '44',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1008,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '49',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1009,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '51',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1010,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '56',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1011,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '63',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1012,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '68',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1013,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '70',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1014,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '75',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1015,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '82',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1016,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '87',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1017,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '94',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1018,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '99',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1019,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '102',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1020,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '107',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1021,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '114',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1022,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '119',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1023,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '121',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1024,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '126',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1025,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '133',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1026,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '138',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1027,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '140',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1028,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '145',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1029,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '152',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1030,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '157',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1031,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '164',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1032,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '169',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1033,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '171',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1034,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '176',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1035,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '183',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1036,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '188',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1037,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '190',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1038,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '195',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1039,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '203',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1040,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '208',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1041,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '210',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1042,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '215',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1043,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '222',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1044,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '227',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1045,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '234',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1046,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '239',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1047,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '241',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1048,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '246',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1049,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '253',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1050,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '258',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1051,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '260',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1052,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '265',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1053,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '272',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1054,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '277',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1055,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '284',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1056,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '289',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1057,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '291',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1058,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '296',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1059,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '304',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1060,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '309',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1061,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '311',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1062,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '316',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1063,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '323',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1064,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '328',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1065,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '330',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1066,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '335',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1067,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '342',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1068,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '347',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1069,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '354',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1070,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '359',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1071,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '361',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1072,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '366',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1073,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '373',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1074,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '378',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1075,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '380',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1076,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '385',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1077,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '392',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1078,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '397',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1079,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '400',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1080,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '405',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1081,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '412',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1082,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '417',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1083,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '424',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1084,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '429',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1085,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '431',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1086,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '436',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1087,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '443',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1088,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '448',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1089,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '450',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1090,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '455',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1091,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '462',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1092,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '467',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1093,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '474',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1094,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '479',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1095,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '481',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1096,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '486',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1097,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '493',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1098,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '498',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1099,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '501',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1100,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '506',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1101,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '513',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1102,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '518',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1103,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '520',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1104,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '525',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1105,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '532',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1106,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '537',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1107,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '544',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1108,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '549',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1109,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '551',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1110,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '556',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1111,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '563',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1112,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '568',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1113,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '570',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1114,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '575',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1115,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '582',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1116,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '587',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1117,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '594',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1118,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '599',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1119,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '602',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1120,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '607',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1121,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '614',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1122,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '619',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1123,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '621',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1124,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '626',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1125,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '633',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1126,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '638',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1127,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '640',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1128,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '645',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1129,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '652',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1130,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '657',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1131,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '664',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1132,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '669',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1133,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '671',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1134,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '676',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1135,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '683',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1136,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '688',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1137,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '690',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1138,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '695',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1139,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '703',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1140,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '708',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1141,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '710',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1142,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '715',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1143,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '722',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1144,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '727',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1145,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '734',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1146,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '739',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1147,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '741',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1148,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '746',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1149,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '753',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1150,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '758',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1151,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '760',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1152,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '765',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1153,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '772',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1154,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '777',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1155,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '784',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1156,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '789',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1157,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '791',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1158,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '796',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1159,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '804',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1160,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '809',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1161,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '811',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1162,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '816',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1163,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '823',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1164,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '828',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1165,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '830',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1166,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '835',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1167,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '842',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1168,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '847',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1169,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '854',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1170,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '859',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1171,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '861',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1172,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '866',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1173,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '873',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1174,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '878',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1175,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '880',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1176,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '885',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1177,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '892',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1178,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '897',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
# ...
#     '_type': '_doc',
#     '_id': '700',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1940,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '705',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1941,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '712',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1942,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '717',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1943,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '724',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1944,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '729',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1945,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '731',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1946,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '736',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1947,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '743',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1948,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '748',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1949,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '750',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1950,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '755',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1951,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '762',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1952,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '767',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1953,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '774',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1954,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '779',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1955,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '781',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1956,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '786',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1957,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '793',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1958,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '798',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1959,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '801',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1960,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '806',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1961,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '813',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1962,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '818',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1963,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '820',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1964,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '825',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1965,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '832',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1966,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '837',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1967,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '844',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1968,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '849',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1969,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '851',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1970,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '856',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1971,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '863',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1972,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '868',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1973,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '870',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1974,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '875',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1975,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '882',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1976,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '887',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1977,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '894',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1978,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '899',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1979,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '902',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1980,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '907',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1981,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '914',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1982,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '919',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1983,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '921',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1984,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '926',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1985,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '933',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1986,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '938',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1987,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '940',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1988,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '945',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1989,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '952',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1990,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '957',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1991,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '964',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1992,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '969',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1993,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '971',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1994,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '976',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1995,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '983',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1996,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '988',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1997,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '990',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1998,
#     '_primary_term': 1,
#     'status': 200}},
#   {'index': {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '995',
#     '_version': 2,
#     'result': 'updated',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1999,
#     '_primary_term': 1,
#     'status': 200}}]}

# %%
r = requests.get("http://localhost:9200/_cat/indices?v")
print(r.text)
# Out:
# health status index    uuid                   pri rep docs.count docs.deleted store.size pri.store.size
# yellow open   bank     U8Pq9fF_SO-qmNwuVGYzLg   1   1       1000            0    414.3kb        414.3kb
# yellow open   megacorp thAuJyrPQW6XLloDmsJrCw   1   1          3            0      6.5kb          6.5kb
# yellow open   bank2    gzKAZhcPSkmnAb9P1J3bpA   1   1         18            0     40.1kb         40.1kb
# yellow open   acl      cw7p1xwXTyyNGD12--8xUw   1   1         11            0    462.2kb        462.2kb

# %%
# 尝试一下json文件不加index,能否使用自动序号

with open('accounts2.json', 'r') as f1:
    data = f1.read()
url = 'http://localhost:9200/bank2/test1/_bulk?pretty&refresh'
headers = {'Content-Type': 'application/json'}

r = requests.post(url = url, headers = headers, data=data)
json.loads(r.text)
# Out:
# {'took': 29,
#  'errors': False,
#  'items': [{'index': {'_index': 'bank2',
#     '_type': 'test1',
#     '_id': '9f6e6800cfae7749eb6c486619254b9c',
#     '_version': 1,
#     'result': 'created',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 15,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'bank2',
#     '_type': 'test1',
#     '_id': 'T78o028BwZMdlpIKYiMN',
#     '_version': 1,
#     'result': 'created',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 16,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'bank2',
#     '_type': 'test1',
#     '_id': 'UL8o028BwZMdlpIKYiMN',
#     '_version': 1,
#     'result': 'created',
#     'forced_refresh': True,
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 17,
#     '_primary_term': 1,
#     'status': 201}}]}

# %% [markdown]
# # Start searchingedit
#
# 源数据:
#
# ```json
# {"account_number":1,"balance":39225,"firstname":"Amber","lastname":"Duke","age":32,"gender":"M","address":"880 Holmes Lane","employer":"Pyrami","email":"amberduke@pyrami.com","city":"Brogan","state":"IL"}
# ```

# %%
# 查找所有; 按照某字段升序排列
data = {
  "query": { "match_all": {} },
  "sort": [
    { "account_number": "asc" }
  ]
}
headers = {'Content-Type': 'application/json'}

r = requests.get("http://localhost:9200/bank/_search", headers = headers, data = json.dumps(data))
json.loads(r.text)
# Out:
# {'took': 78,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1000, 'relation': 'eq'},
#   'max_score': None,
#   'hits': [{'_index': 'bank',
#     '_type': '_doc',
#     '_id': '0',
#     '_score': None,
#     '_source': {'account_number': 0,
#      'balance': 16623,
#      'firstname': 'Bradshaw',
#      'lastname': 'Mckenzie',
#      'age': 29,
#      'gender': 'F',
#      'address': '244 Columbus Place',
#      'employer': 'Euron',
#      'email': 'bradshawmckenzie@euron.com',
#      'city': 'Hobucken',
#      'state': 'CO'},
#     'sort': [0]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '1',
#     '_score': None,
#     '_source': {'account_number': 1,
#      'balance': 39225,
#      'firstname': 'Amber',
#      'lastname': 'Duke',
#      'age': 32,
#      'gender': 'M',
#      'address': '880 Holmes Lane',
#      'employer': 'Pyrami',
#      'email': 'amberduke@pyrami.com',
#      'city': 'Brogan',
#      'state': 'IL'},
#     'sort': [1]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '2',
#     '_score': None,
#     '_source': {'account_number': 2,
#      'balance': 28838,
#      'firstname': 'Roberta',
#      'lastname': 'Bender',
#      'age': 22,
#      'gender': 'F',
#      'address': '560 Kingsway Place',
#      'employer': 'Chillium',
#      'email': 'robertabender@chillium.com',
#      'city': 'Bennett',
#      'state': 'LA'},
#     'sort': [2]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '3',
#     '_score': None,
#     '_source': {'account_number': 3,
#      'balance': 44947,
#      'firstname': 'Levine',
#      'lastname': 'Burks',
#      'age': 26,
#      'gender': 'F',
#      'address': '328 Wilson Avenue',
#      'employer': 'Amtap',
#      'email': 'levineburks@amtap.com',
#      'city': 'Cochranville',
#      'state': 'HI'},
#     'sort': [3]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '4',
#     '_score': None,
#     '_source': {'account_number': 4,
#      'balance': 27658,
#      'firstname': 'Rodriquez',
#      'lastname': 'Flores',
#      'age': 31,
#      'gender': 'F',
#      'address': '986 Wyckoff Avenue',
#      'employer': 'Tourmania',
#      'email': 'rodriquezflores@tourmania.com',
#      'city': 'Eastvale',
#      'state': 'HI'},
#     'sort': [4]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '5',
#     '_score': None,
#     '_source': {'account_number': 5,
#      'balance': 29342,
#      'firstname': 'Leola',
#      'lastname': 'Stewart',
#      'age': 30,
#      'gender': 'F',
#      'address': '311 Elm Place',
#      'employer': 'Diginetic',
#      'email': 'leolastewart@diginetic.com',
#      'city': 'Fairview',
#      'state': 'NJ'},
#     'sort': [5]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '6',
#     '_score': None,
#     '_source': {'account_number': 6,
#      'balance': 5686,
#      'firstname': 'Hattie',
#      'lastname': 'Bond',
#      'age': 36,
#      'gender': 'M',
#      'address': '671 Bristol Street',
#      'employer': 'Netagy',
#      'email': 'hattiebond@netagy.com',
#      'city': 'Dante',
#      'state': 'TN'},
#     'sort': [6]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '7',
#     '_score': None,
#     '_source': {'account_number': 7,
#      'balance': 39121,
#      'firstname': 'Levy',
#      'lastname': 'Richard',
#      'age': 22,
#      'gender': 'M',
#      'address': '820 Logan Street',
#      'employer': 'Teraprene',
#      'email': 'levyrichard@teraprene.com',
#      'city': 'Shrewsbury',
#      'state': 'MO'},
#     'sort': [7]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '8',
#     '_score': None,
#     '_source': {'account_number': 8,
#      'balance': 48868,
#      'firstname': 'Jan',
#      'lastname': 'Burns',
#      'age': 35,
#      'gender': 'M',
#      'address': '699 Visitation Place',
#      'employer': 'Glasstep',
#      'email': 'janburns@glasstep.com',
#      'city': 'Wakulla',
#      'state': 'AZ'},
#     'sort': [8]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '9',
#     '_score': None,
#     '_source': {'account_number': 9,
#      'balance': 24776,
#      'firstname': 'Opal',
#      'lastname': 'Meadows',
#      'age': 39,
#      'gender': 'M',
#      'address': '963 Neptune Avenue',
#      'employer': 'Cedward',
#      'email': 'opalmeadows@cedward.com',
#      'city': 'Olney',
#      'state': 'OH'},
#     'sort': [9]}]}}

# %%
# 查找所有; 按照某字段升序排列; gets hits 10 through 19
data = {
  "query": { "match_all": {} },
  "sort": [
    { "account_number": "asc" }
  ],
  "from": 10,
  "size": 10
}
headers = {'Content-Type': 'application/json'}

r = requests.get("http://localhost:9200/bank/_search", headers = headers, data = json.dumps(data))
json.loads(r.text)
# Out:
# {'took': 8,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1000, 'relation': 'eq'},
#   'max_score': None,
#   'hits': [{'_index': 'bank',
#     '_type': '_doc',
#     '_id': '10',
#     '_score': None,
#     '_source': {'account_number': 10,
#      'balance': 46170,
#      'firstname': 'Dominique',
#      'lastname': 'Park',
#      'age': 37,
#      'gender': 'F',
#      'address': '100 Gatling Place',
#      'employer': 'Conjurica',
#      'email': 'dominiquepark@conjurica.com',
#      'city': 'Omar',
#      'state': 'NJ'},
#     'sort': [10]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '11',
#     '_score': None,
#     '_source': {'account_number': 11,
#      'balance': 20203,
#      'firstname': 'Jenkins',
#      'lastname': 'Haney',
#      'age': 20,
#      'gender': 'M',
#      'address': '740 Ferry Place',
#      'employer': 'Qimonk',
#      'email': 'jenkinshaney@qimonk.com',
#      'city': 'Steinhatchee',
#      'state': 'GA'},
#     'sort': [11]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '12',
#     '_score': None,
#     '_source': {'account_number': 12,
#      'balance': 37055,
#      'firstname': 'Stafford',
#      'lastname': 'Brock',
#      'age': 20,
#      'gender': 'F',
#      'address': '296 Wythe Avenue',
#      'employer': 'Uncorp',
#      'email': 'staffordbrock@uncorp.com',
#      'city': 'Bend',
#      'state': 'AL'},
#     'sort': [12]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '13',
#     '_score': None,
#     '_source': {'account_number': 13,
#      'balance': 32838,
#      'firstname': 'Nanette',
#      'lastname': 'Bates',
#      'age': 28,
#      'gender': 'F',
#      'address': '789 Madison Street',
#      'employer': 'Quility',
#      'email': 'nanettebates@quility.com',
#      'city': 'Nogal',
#      'state': 'VA'},
#     'sort': [13]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '14',
#     '_score': None,
#     '_source': {'account_number': 14,
#      'balance': 20480,
#      'firstname': 'Erma',
#      'lastname': 'Kane',
#      'age': 39,
#      'gender': 'F',
#      'address': '661 Vista Place',
#      'employer': 'Stockpost',
#      'email': 'ermakane@stockpost.com',
#      'city': 'Chamizal',
#      'state': 'NY'},
#     'sort': [14]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '15',
#     '_score': None,
#     '_source': {'account_number': 15,
#      'balance': 43456,
#      'firstname': 'Bobbie',
#      'lastname': 'Sexton',
#      'age': 21,
#      'gender': 'M',
#      'address': '232 Sedgwick Place',
#      'employer': 'Zytrex',
#      'email': 'bobbiesexton@zytrex.com',
#      'city': 'Hendersonville',
#      'state': 'CA'},
#     'sort': [15]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '16',
#     '_score': None,
#     '_source': {'account_number': 16,
#      'balance': 35883,
#      'firstname': 'Adrian',
#      'lastname': 'Pitts',
#      'age': 34,
#      'gender': 'F',
#      'address': '963 Fay Court',
#      'employer': 'Combogene',
#      'email': 'adrianpitts@combogene.com',
#      'city': 'Remington',
#      'state': 'SD'},
#     'sort': [16]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '17',
#     '_score': None,
#     '_source': {'account_number': 17,
#      'balance': 7831,
#      'firstname': 'Bessie',
#      'lastname': 'Orr',
#      'age': 31,
#      'gender': 'F',
#      'address': '239 Hinsdale Street',
#      'employer': 'Skyplex',
#      'email': 'bessieorr@skyplex.com',
#      'city': 'Graball',
#      'state': 'FL'},
#     'sort': [17]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '18',
#     '_score': None,
#     '_source': {'account_number': 18,
#      'balance': 4180,
#      'firstname': 'Dale',
#      'lastname': 'Adams',
#      'age': 33,
#      'gender': 'M',
#      'address': '467 Hutchinson Court',
#      'employer': 'Boink',
#      'email': 'daleadams@boink.com',
#      'city': 'Orick',
#      'state': 'MD'},
#     'sort': [18]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '19',
#     '_score': None,
#     '_source': {'account_number': 19,
#      'balance': 27894,
#      'firstname': 'Schwartz',
#      'lastname': 'Buchanan',
#      'age': 28,
#      'gender': 'F',
#      'address': '449 Mersereau Court',
#      'employer': 'Sybixtex',
#      'email': 'schwartzbuchanan@sybixtex.com',
#      'city': 'Greenwich',
#      'state': 'KS'},
#     'sort': [19]}]}}

# %%
# 查找特定字段
data = {
  "query": { "match": { "address": "mill lane" } }
}
headers = {'Content-Type': 'application/json'}

r = requests.get("http://localhost:9200/bank/_search", headers = headers, data = json.dumps(data))
json.loads(r.text)
# Out:
# {'took': 22,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 19, 'relation': 'eq'},
#   'max_score': 9.507477,
#   'hits': [{'_index': 'bank',
#     '_type': '_doc',
#     '_id': '136',
#     '_score': 9.507477,
#     '_source': {'account_number': 136,
#      'balance': 45801,
#      'firstname': 'Winnie',
#      'lastname': 'Holland',
#      'age': 38,
#      'gender': 'M',
#      'address': '198 Mill Lane',
#      'employer': 'Neteria',
#      'email': 'winnieholland@neteria.com',
#      'city': 'Urie',
#      'state': 'IL'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '970',
#     '_score': 5.4032025,
#     '_source': {'account_number': 970,
#      'balance': 19648,
#      'firstname': 'Forbes',
#      'lastname': 'Wallace',
#      'age': 28,
#      'gender': 'M',
#      'address': '990 Mill Road',
#      'employer': 'Pheast',
#      'email': 'forbeswallace@pheast.com',
#      'city': 'Lopezo',
#      'state': 'AK'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '345',
#     '_score': 5.4032025,
#     '_source': {'account_number': 345,
#      'balance': 9812,
#      'firstname': 'Parker',
#      'lastname': 'Hines',
#      'age': 38,
#      'gender': 'M',
#      'address': '715 Mill Avenue',
#      'employer': 'Baluba',
#      'email': 'parkerhines@baluba.com',
#      'city': 'Blackgum',
#      'state': 'KY'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '472',
#     '_score': 5.4032025,
#     '_source': {'account_number': 472,
#      'balance': 25571,
#      'firstname': 'Lee',
#      'lastname': 'Long',
#      'age': 32,
#      'gender': 'F',
#      'address': '288 Mill Street',
#      'employer': 'Comverges',
#      'email': 'leelong@comverges.com',
#      'city': 'Movico',
#      'state': 'MT'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '1',
#     '_score': 4.1042743,
#     '_source': {'account_number': 1,
#      'balance': 39225,
#      'firstname': 'Amber',
#      'lastname': 'Duke',
#      'age': 32,
#      'gender': 'M',
#      'address': '880 Holmes Lane',
#      'employer': 'Pyrami',
#      'email': 'amberduke@pyrami.com',
#      'city': 'Brogan',
#      'state': 'IL'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '70',
#     '_score': 4.1042743,
#     '_source': {'account_number': 70,
#      'balance': 38172,
#      'firstname': 'Deidre',
#      'lastname': 'Thompson',
#      'age': 33,
#      'gender': 'F',
#      'address': '685 School Lane',
#      'employer': 'Netplode',
#      'email': 'deidrethompson@netplode.com',
#      'city': 'Chestnut',
#      'state': 'GA'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '556',
#     '_score': 4.1042743,
#     '_source': {'account_number': 556,
#      'balance': 36420,
#      'firstname': 'Collier',
#      'lastname': 'Odonnell',
#      'age': 35,
#      'gender': 'M',
#      'address': '591 Nolans Lane',
#      'employer': 'Sultraxin',
#      'email': 'collierodonnell@sultraxin.com',
#      'city': 'Fulford',
#      'state': 'MD'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '568',
#     '_score': 4.1042743,
#     '_source': {'account_number': 568,
#      'balance': 36628,
#      'firstname': 'Lesa',
#      'lastname': 'Maynard',
#      'age': 29,
#      'gender': 'F',
#      'address': '295 Whitty Lane',
#      'employer': 'Coash',
#      'email': 'lesamaynard@coash.com',
#      'city': 'Broadlands',
#      'state': 'VT'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '715',
#     '_score': 4.1042743,
#     '_source': {'account_number': 715,
#      'balance': 23734,
#      'firstname': 'Tammi',
#      'lastname': 'Hodge',
#      'age': 24,
#      'gender': 'M',
#      'address': '865 Church Lane',
#      'employer': 'Netur',
#      'email': 'tammihodge@netur.com',
#      'city': 'Lacomb',
#      'state': 'KS'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '449',
#     '_score': 4.1042743,
#     '_source': {'account_number': 449,
#      'balance': 41950,
#      'firstname': 'Barnett',
#      'lastname': 'Cantrell',
#      'age': 39,
#      'gender': 'F',
#      'address': '945 Bedell Lane',
#      'employer': 'Zentility',
#      'email': 'barnettcantrell@zentility.com',
#      'city': 'Swartzville',
#      'state': 'ND'}}]}}

# %%
# 查找词组
data = {
  "query": { "match_phrase": { "address": "mill lane" } }
}
headers = {'Content-Type': 'application/json'}

r = requests.get("http://localhost:9200/bank/_search", headers = headers, data = json.dumps(data))
json.loads(r.text)
# Out:
# {'took': 15,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1, 'relation': 'eq'},
#   'max_score': 9.507477,
#   'hits': [{'_index': 'bank',
#     '_type': '_doc',
#     '_id': '136',
#     '_score': 9.507477,
#     '_source': {'account_number': 136,
#      'balance': 45801,
#      'firstname': 'Winnie',
#      'lastname': 'Holland',
#      'age': 38,
#      'gender': 'M',
#      'address': '198 Mill Lane',
#      'employer': 'Neteria',
#      'email': 'winnieholland@neteria.com',
#      'city': 'Urie',
#      'state': 'IL'}}]}}

# %%
# 组合筛选: 年龄==40 不住Idaho
data = {
  "query": {
    "bool": {
      "must": [
        { "match": { "age": "40" } }
      ],
      "must_not": [
        { "match": { "state": "ID" } }
      ]
    }
  }
}
headers = {'Content-Type': 'application/json'}

r = requests.get("http://localhost:9200/bank/_search", headers = headers, data = json.dumps(data))
json.loads(r.text)
# Out:
# {'took': 3,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 43, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'bank',
#     '_type': '_doc',
#     '_id': '474',
#     '_score': 1.0,
#     '_source': {'account_number': 474,
#      'balance': 35896,
#      'firstname': 'Obrien',
#      'lastname': 'Walton',
#      'age': 40,
#      'gender': 'F',
#      'address': '192 Ide Court',
#      'employer': 'Suremax',
#      'email': 'obrienwalton@suremax.com',
#      'city': 'Crucible',
#      'state': 'UT'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '479',
#     '_score': 1.0,
#     '_source': {'account_number': 479,
#      'balance': 31865,
#      'firstname': 'Cameron',
#      'lastname': 'Ross',
#      'age': 40,
#      'gender': 'M',
#      'address': '904 Bouck Court',
#      'employer': 'Telpod',
#      'email': 'cameronross@telpod.com',
#      'city': 'Nord',
#      'state': 'MO'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '549',
#     '_score': 1.0,
#     '_source': {'account_number': 549,
#      'balance': 1932,
#      'firstname': 'Jacqueline',
#      'lastname': 'Maxwell',
#      'age': 40,
#      'gender': 'M',
#      'address': '444 Schenck Place',
#      'employer': 'Fuelworks',
#      'email': 'jacquelinemaxwell@fuelworks.com',
#      'city': 'Oretta',
#      'state': 'OR'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '878',
#     '_score': 1.0,
#     '_source': {'account_number': 878,
#      'balance': 49159,
#      'firstname': 'Battle',
#      'lastname': 'Blackburn',
#      'age': 40,
#      'gender': 'F',
#      'address': '234 Hendrix Street',
#      'employer': 'Zilphur',
#      'email': 'battleblackburn@zilphur.com',
#      'city': 'Wanamie',
#      'state': 'PA'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '885',
#     '_score': 1.0,
#     '_source': {'account_number': 885,
#      'balance': 31661,
#      'firstname': 'Valdez',
#      'lastname': 'Roberson',
#      'age': 40,
#      'gender': 'F',
#      'address': '227 Scholes Street',
#      'employer': 'Delphide',
#      'email': 'valdezroberson@delphide.com',
#      'city': 'Chilton',
#      'state': 'MT'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '948',
#     '_score': 1.0,
#     '_source': {'account_number': 948,
#      'balance': 37074,
#      'firstname': 'Sargent',
#      'lastname': 'Powers',
#      'age': 40,
#      'gender': 'M',
#      'address': '532 Fiske Place',
#      'employer': 'Accuprint',
#      'email': 'sargentpowers@accuprint.com',
#      'city': 'Umapine',
#      'state': 'AK'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '998',
#     '_score': 1.0,
#     '_source': {'account_number': 998,
#      'balance': 16869,
#      'firstname': 'Letha',
#      'lastname': 'Baker',
#      'age': 40,
#      'gender': 'F',
#      'address': '206 Llama Court',
#      'employer': 'Dognosis',
#      'email': 'lethabaker@dognosis.com',
#      'city': 'Dunlo',
#      'state': 'WV'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '40',
#     '_score': 1.0,
#     '_source': {'account_number': 40,
#      'balance': 33882,
#      'firstname': 'Pace',
#      'lastname': 'Molina',
#      'age': 40,
#      'gender': 'M',
#      'address': '263 Ovington Court',
#      'employer': 'Cytrak',
#      'email': 'pacemolina@cytrak.com',
#      'city': 'Silkworth',
#      'state': 'OR'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '165',
#     '_score': 1.0,
#     '_source': {'account_number': 165,
#      'balance': 18956,
#      'firstname': 'Sims',
#      'lastname': 'Mckay',
#      'age': 40,
#      'gender': 'F',
#      'address': '205 Jackson Street',
#      'employer': 'Comtour',
#      'email': 'simsmckay@comtour.com',
#      'city': 'Tilden',
#      'state': 'DC'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '177',
#     '_score': 1.0,
#     '_source': {'account_number': 177,
#      'balance': 48972,
#      'firstname': 'Harris',
#      'lastname': 'Gross',
#      'age': 40,
#      'gender': 'F',
#      'address': '468 Suydam Street',
#      'employer': 'Kidstock',
#      'email': 'harrisgross@kidstock.com',
#      'city': 'Yettem',
#      'state': 'KY'}}]}}

# %%
# 组合筛选: 范围筛选,余额在2w-3w之间.
data = {
  "query": {
    "bool": {
      "must": { "match_all": {} },
      "filter": {
        "range": {
          "balance": {
            "gte": 20000,
            "lte": 30000
          }
        }
      }
    }
  }
}
headers = {'Content-Type': 'application/json'}

r = requests.get("http://localhost:9200/bank/_search", headers = headers, data = json.dumps(data))
json.loads(r.text)
# Out:
# {'took': 7,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 217, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'bank',
#     '_type': '_doc',
#     '_id': '49',
#     '_score': 1.0,
#     '_source': {'account_number': 49,
#      'balance': 29104,
#      'firstname': 'Fulton',
#      'lastname': 'Holt',
#      'age': 23,
#      'gender': 'F',
#      'address': '451 Humboldt Street',
#      'employer': 'Anocha',
#      'email': 'fultonholt@anocha.com',
#      'city': 'Sunriver',
#      'state': 'RI'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '102',
#     '_score': 1.0,
#     '_source': {'account_number': 102,
#      'balance': 29712,
#      'firstname': 'Dena',
#      'lastname': 'Olson',
#      'age': 27,
#      'gender': 'F',
#      'address': '759 Newkirk Avenue',
#      'employer': 'Hinway',
#      'email': 'denaolson@hinway.com',
#      'city': 'Choctaw',
#      'state': 'NJ'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '133',
#     '_score': 1.0,
#     '_source': {'account_number': 133,
#      'balance': 26135,
#      'firstname': 'Deena',
#      'lastname': 'Richmond',
#      'age': 36,
#      'gender': 'F',
#      'address': '646 Underhill Avenue',
#      'employer': 'Sunclipse',
#      'email': 'deenarichmond@sunclipse.com',
#      'city': 'Austinburg',
#      'state': 'SC'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '140',
#     '_score': 1.0,
#     '_source': {'account_number': 140,
#      'balance': 26696,
#      'firstname': 'Cotton',
#      'lastname': 'Christensen',
#      'age': 32,
#      'gender': 'M',
#      'address': '878 Schermerhorn Street',
#      'employer': 'Prowaste',
#      'email': 'cottonchristensen@prowaste.com',
#      'city': 'Mayfair',
#      'state': 'LA'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '203',
#     '_score': 1.0,
#     '_source': {'account_number': 203,
#      'balance': 21890,
#      'firstname': 'Eve',
#      'lastname': 'Wyatt',
#      'age': 33,
#      'gender': 'M',
#      'address': '435 Furman Street',
#      'employer': 'Assitia',
#      'email': 'evewyatt@assitia.com',
#      'city': 'Jamestown',
#      'state': 'MN'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '239',
#     '_score': 1.0,
#     '_source': {'account_number': 239,
#      'balance': 25719,
#      'firstname': 'Chang',
#      'lastname': 'Boyer',
#      'age': 36,
#      'gender': 'M',
#      'address': '895 Brigham Street',
#      'employer': 'Qaboos',
#      'email': 'changboyer@qaboos.com',
#      'city': 'Belgreen',
#      'state': 'NH'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '241',
#     '_score': 1.0,
#     '_source': {'account_number': 241,
#      'balance': 25379,
#      'firstname': 'Schroeder',
#      'lastname': 'Harrington',
#      'age': 26,
#      'gender': 'M',
#      'address': '610 Tapscott Avenue',
#      'employer': 'Otherway',
#      'email': 'schroederharrington@otherway.com',
#      'city': 'Ebro',
#      'state': 'TX'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '246',
#     '_score': 1.0,
#     '_source': {'account_number': 246,
#      'balance': 28405,
#      'firstname': 'Katheryn',
#      'lastname': 'Foster',
#      'age': 21,
#      'gender': 'F',
#      'address': '259 Kane Street',
#      'employer': 'Quantalia',
#      'email': 'katherynfoster@quantalia.com',
#      'city': 'Bath',
#      'state': 'TX'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '253',
#     '_score': 1.0,
#     '_source': {'account_number': 253,
#      'balance': 20240,
#      'firstname': 'Melissa',
#      'lastname': 'Gould',
#      'age': 31,
#      'gender': 'M',
#      'address': '440 Fuller Place',
#      'employer': 'Buzzopia',
#      'email': 'melissagould@buzzopia.com',
#      'city': 'Lumberton',
#      'state': 'MD'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '277',
#     '_score': 1.0,
#     '_source': {'account_number': 277,
#      'balance': 29564,
#      'firstname': 'Romero',
#      'lastname': 'Lott',
#      'age': 31,
#      'gender': 'M',
#      'address': '456 Danforth Street',
#      'employer': 'Plasto',
#      'email': 'romerolott@plasto.com',
#      'city': 'Vincent',
#      'state': 'VT'}}]}}

# %% [markdown]
# ### 摸索

# %%
# 返回指定字段值 :"firstname","lastname"  query_string能包含或且关系
data = {
    "_source": {
        "include": [
                "firstname",
                "lastname",
                "address"
            ]
            },
    "from":0,
    "size":5,    
    "query": {
        "query_string" : {
            "query" : "(Mill Street) OR (Mill Avenue)",
            "default_field" : "address"
        }
    }
    }
headers = {'Content-Type': 'application/json'}

r = requests.get("http://localhost:9200/bank/_search", headers = headers, data = json.dumps(data))
json.loads(r.text)
# Out:
# {'took': 16,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 601, 'relation': 'eq'},
#   'max_score': 12.34643,
#   'hits': [{'_index': 'bank',
#     '_type': '_doc',
#     '_id': '345',
#     '_score': 12.34643,
#     '_source': {'firstname': 'Parker',
#      'address': '715 Mill Avenue',
#      'lastname': 'Hines'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '472',
#     '_score': 11.760358,
#     '_source': {'firstname': 'Lee',
#      'address': '288 Mill Street',
#      'lastname': 'Long'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '970',
#     '_score': 10.806405,
#     '_source': {'firstname': 'Forbes',
#      'address': '990 Mill Road',
#      'lastname': 'Wallace'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '136',
#     '_score': 10.806405,
#     '_source': {'firstname': 'Winnie',
#      'address': '198 Mill Lane',
#      'lastname': 'Holland'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '25',
#     '_score': 1.5400246,
#     '_source': {'firstname': 'Virginia',
#      'address': '171 Putnam Avenue',
#      'lastname': 'Ayala'}}]}}

# %%
# 返回指定字段值; 做聚合,只能对数值型字段进行count
data = {
    "_source": {
        "include": [
            "balance",
            "address"
            ]
            },
    "from":0,
    "size":1,

    "aggs" : {
        "xxxx1" : { "value_count" : { "field" : "balance" } }
    }
}
headers = {'Content-Type': 'application/json'}

r = requests.get("http://localhost:9200/bank/_search", headers = headers, data = json.dumps(data))
json.loads(r.text)
# Out:
# {'took': 4,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1000, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'bank',
#     '_type': '_doc',
#     '_id': '1',
#     '_score': 1.0,
#     '_source': {'address': '880 Holmes Lane', 'balance': 39225}}]},
#  'aggregations': {'xxxx1': {'value': 1000}}}

# %% [raw]
# https://stackoverflow.com/questions/45617814/elasticsearch-count-of-matches-per-document/55943306#55943306?newreg=c6005fc419744741ac5f067c5579f601

# %%
key_word = "Holmes Lane"

base_script = {}
base_script["嘻嘻嘻嘻嘻嘻"] = {}
base_script["嘻嘻嘻嘻嘻嘻"]["script"] = {}
base_script["嘻嘻嘻嘻嘻嘻"]["script"]["lang"] = "painless"
base_script["嘻嘻嘻嘻嘻嘻"]["script"]["source"] = f"""
int count = 0;
if(doc['address.keyword'].size() > 0 && doc['address.keyword'].value.indexOf(params.phrase)!=-1) count++;
return count;        
"""
base_script["嘻嘻嘻嘻嘻嘻"]["script"]["params"] = {}
base_script["嘻嘻嘻嘻嘻嘻"]["script"]["params"]["phrase"] = key_word
base_script
# Out:
# {'嘻嘻嘻嘻嘻嘻': {'script': {'lang': 'painless',
#    'source': "\nint count = 0;\nif(doc['address.keyword'].size() > 0 && doc['address.keyword'].value.indexOf(params.phrase)!=-1) count++;\nreturn count;        \n",
#    'params': {'phrase': 'Holmes Lane'}}}}

# %%
# 统计特定词语的词频
data = {
    "_source": {
        "include": [
            "balance",
            "address"
            ]
            },
    "from":0,
    "size":5,
    "sort": { "_id": { "order": "asc" }},
  "script_fields": base_script
}
headers = {'Content-Type': 'application/json'}

r = requests.get("http://localhost:9200/bank/_search", headers = headers, data = json.dumps(data))
json.loads(r.text)
# Out:
# {'took': 3,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1000, 'relation': 'eq'},
#   'max_score': None,
#   'hits': [{'_index': 'bank',
#     '_type': '_doc',
#     '_id': '0',
#     '_score': None,
#     '_source': {'address': '244 Columbus Place', 'balance': 16623},
#     'fields': {'嘻嘻嘻嘻嘻嘻': [0]},
#     'sort': ['0']},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '1',
#     '_score': None,
#     '_source': {'address': '880 Holmes Lane', 'balance': 39225},
#     'fields': {'嘻嘻嘻嘻嘻嘻': [1]},
#     'sort': ['1']},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '10',
#     '_score': None,
#     '_source': {'address': '100 Gatling Place', 'balance': 46170},
#     'fields': {'嘻嘻嘻嘻嘻嘻': [0]},
#     'sort': ['10']},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '100',
#     '_score': None,
#     '_source': {'address': '696 Ryder Avenue', 'balance': 29869},
#     'fields': {'嘻嘻嘻嘻嘻嘻': [0]},
#     'sort': ['100']},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '101',
#     '_score': None,
#     '_source': {'address': '972 Lincoln Place', 'balance': 43400},
#     'fields': {'嘻嘻嘻嘻嘻嘻': [0]},
#     'sort': ['101']}]}}

# %%
j = json.loads(r.text)
lines = []
jj = j['hits']['hits']
for item in jj:
    one_line = []
    address = item['_source']['address']
    balance = item['_source']['balance']
    temp = [item['fields'][key][0] for key in item['fields'].keys()]
    one_line.append(address)
    one_line.append(balance)
    one_line.extend(temp)
    lines.append(one_line)

# %%
lines
# Out:
# [['244 Columbus Place', 16623, 0],
#  ['880 Holmes Lane', 39225, 1],
#  ['100 Gatling Place', 46170, 0],
#  ['696 Ryder Avenue', 29869, 0],
#  ['972 Lincoln Place', 43400, 0]]

# %% [markdown]
# ## head

# %%
data = {
        "_source": {
        "include": [
            "Name",
            ]
            },
  "query": {
    "bool": {
      "must": [
        { "match": { "Name": "Single-Agent vs. Multi-Agent Techniques for Concurrent Reinforcement Learning of Negotiation Dialogue Policies" } }
      ],
    }
  }
}
headers = {'Content-Type': 'application/json'}

r = requests.get("http://localhost:9200/acl/_search", headers = headers, data = json.dumps(data))
res_json = json.loads(r.text)
res_json
# Out:
# {'took': 10,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 2139, 'relation': 'eq'},
#   'max_score': 52.84863,
#   'hits': [{'_index': 'acl',
#     '_type': '_doc',
#     '_id': 'ad4456a737a69002df2b1b2ee4980da6',
#     '_score': 52.84863,
#     '_source': {'Name': ' Multi-Agent Techniques for Concurrent Reinforcement Learning of Negotiation Dialogue Policies'}},
#    {'_index': 'acl',
#     '_type': '_doc',
#     '_id': '6edd87f77ff1abe602815ade3ecb5f6e',
#     '_score': 13.71889,
#     '_source': {'Name': 'Word-order Biases in Deep-agent Emergent Communication'}},
#    {'_index': 'acl',
#     '_type': '_doc',
#     '_id': 'b0e82af8978f5ae927fcf10ce15d5742',
#     '_score': 13.71889,
#     '_source': {'Name': 'Insights from Building an Open-Ended Conversational Agent'}},
#    {'_index': 'acl',
#     '_type': '_doc',
#     '_id': 'd3feebe9ae18beb1431ba58c714d412b',
#     '_score': 13.451605,
#     '_source': {'Name': 'Improving social relationships in face-to-face human-agent interactions when the agent wants to know user’s likes and dislikes'}},
#    {'_index': 'acl',
#     '_type': '_doc',
#     '_id': '09458204202748e4780c91f2a9cf018f',
#     '_score': 12.452433,
#     '_source': {'Name': 'Towards End-to-End Reinforcement Learning of Dialogue Agents for Information Access'}},
#    {'_index': 'acl',
#     '_type': '_doc',
#     '_id': 'd51b75cb552c8b697169bbe3a68d9e57',
#     '_score': 12.323337,
#     '_source': {'Name': 'FASTDial Abstracting Dialogue Policies for Fast Development of Task Oriented Agents'}},
#    {'_index': 'acl',
#     '_type': '_doc',
#     '_id': '618008bcca4f7ebb726599884579838e',
#     '_score': 11.576288,
#     '_source': {'Name': 'Zara Returns Improved Personality Induction and Adaptation by an Empathetic Virtual Agent'}},
#    {'_index': 'acl',
#     '_type': '_doc',
#     '_id': 'f9dd581d56357a95815487779ef469ac',
#     '_score': 11.085872,
#     '_source': {'Name': 'Comparing Multi-label Classification with Reinforcement Learning for Summarisation of Time-series Data'}},
#    {'_index': 'acl',
#     '_type': '_doc',
#     '_id': 'a42c2754572c53c3b57a5acef0447549',
#     '_score': 10.19139,
#     '_source': {'Name': 'Deep Reinforcement Learning for NLP'}},
#    {'_index': 'acl',
#     '_type': '_doc',
#     '_id': 'd197977d0921459332726683d6494b49',
#     '_score': 9.224191,
#     '_source': {'Name': 'New Transfer Learning Techniques for Disparate Label Sets'}}]}}

# %%
'sad sad sa d.pdf'.split('.pdf')
